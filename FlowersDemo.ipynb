# %%
import numpy as np
import bokeh
from bokeh.plotting import figure, show, output_file, output_notebook
from bokeh.charts import Histogram
from bokeh.sampledata.iris import flowers

output_notebook()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# The bokeh.charts API has moved to a separate 'bkcharts' package.
#
# This compatibility shim will remain until Bokeh 1.0 is released.
# After that, if you want to use this API you will have to install
# the bkcharts package explicitly.
#
#   warn(message)
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="02ac3c9f-749a-4a0b-be5b-18414b282298">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# The flowers dataset is a dataframe with observational values for a number of samples.
# In Python, operations can be called directly on an object by the dot notation.
# View just the top 5 rows by calling the "head" function on the flowers dataframe.

# %%
flowers.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
display(flowers.tail(3))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# Notice that the indexing starts at 0, so the values will range from 0-149.  You can view any range of rows within the dataframe by specifying the start, length, and increment parameters.  The following starts at the 3rd position, will display up to, but not including the 10th row, skipping every second record.

# %%
flowers[3:10:2]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 3           4.6          3.1           1.5          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
flowers.sort_values(by='sepal_length').head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 13           4.3          3.0           1.1          0.1  setosa
# 42           4.4          3.2           1.3          0.2  setosa
# 38           4.4          3.0           1.3          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 41           4.5          2.3           1.3          0.3  setosa

# %%
flowers[flowers.sepal_length < 5]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# 12            4.8          3.0           1.4          0.1      setosa
# 13            4.3          3.0           1.1          0.1      setosa
# 22            4.6          3.6           1.0          0.2      setosa
# 24            4.8          3.4           1.9          0.2      setosa
# 29            4.7          3.2           1.6          0.2      setosa
# 30            4.8          3.1           1.6          0.2      setosa
# 34            4.9          3.1           1.5          0.2      setosa
# 37            4.9          3.6           1.4          0.1      setosa
# 38            4.4          3.0           1.3          0.2      setosa
# 41            4.5          2.3           1.3          0.3      setosa
# 42            4.4          3.2           1.3          0.2      setosa
# 45            4.8          3.0           1.4          0.3      setosa
# 47            4.6          3.2           1.4          0.2      setosa
# 57            4.9          2.4           3.3          1.0  versicolor
# 106           4.9          2.5           4.5          1.7   virginica

# %%
flowers.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
display(flowers["species"].unique())
display(flowers.species.value_counts())
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %%
hist = Histogram(flowers,values='petal_length')
show(hist)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0bd38c25-e446-4971-94c1-711428d08e15"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0bd38c25-e446-4971-94c1-711428d08e15");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0bd38c25-e446-4971-94c1-711428d08e15");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0bd38c25-e446-4971-94c1-711428d08e15' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8f64b73b-cb4b-4742-9f7c-693638b074de":{"roots":{"references":[{"attributes":{"data_source":{"id":"fdca56dc-f39d-4b8d-855c-d1a24f2abbf8","type":"ColumnDataSource"},"glyph":{"id":"b41a7fb6-91a8-493d-b78d-51097044e74a","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"4ed13864-3cf0-4d7f-b23c-8cd2d4d2c8e7","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7939387c-e208-475a-9342-18dc97fea486","type":"Rect"},{"attributes":{},"id":"7c6852c6-a44f-470b-ac28-7af867ad399c","type":"LinearScale"},{"attributes":{"callback":null,"end":7.0975,"start":0.8025},"id":"bf4286a2-aa6b-42a1-8384-44b50738149e","type":"Range1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"668832cd-7d29-4bf1-9b98-78253798f9ae","type":"Rect"},{"attributes":{"below":[{"id":"3c69f2cf-d622-462e-8539-5ad914bca50f","type":"LinearAxis"}],"css_classes":null,"left":[{"id":
type":"HelpTool"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"field":"fill_color"},"line_color":{"field":"line_color"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"0ccb3d8b-6bd1-45ec-8cb1-54a1de8c558a","type":"Circle"},{"attributes":{"callback":null},"id":"30115007-5040-4949-a2ef-5b33069c382b","type":"DataRange1d"},{"attributes":{},"id":"9d9152c6-3c74-4648-ba98-3b3ea1b6a36d","type":"ToolEvents"},{"attributes":{"plot":null,"text":"Iris Morphology"},"id":"23b64bd7-3733-4c39-b525-894f80a1a13f","type":"Title"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4ebcb147-7bfc-4d25-a9a0-7c24cc7e539c","type": ...

# %% [markdown]
# Unfortunately, adding a legend is not straightforward using this method (that I know of), since the colors are not directly attached to the data.  It's best to not alter the original data, so we will create a temporary copy of the data frame and add a column called "colors" as defined by the color map.  The "for" loop will then iterate over each of the species varieties, pull the rows that match that variety, then define the circle location based on the petal length (x-axis) and width (y-axis), with the according color and legend label.

# %%
colormap = {'setosa': 'red', 'versicolor': 'green', 'virginica': 'blue'}
temp = flowers
temp['colors'] = [colormap[x] for x in temp['species']]
temp = temp.set_index("species")
display(temp.index)
p = figure(title = "Iris Morphology")
p.xaxis.axis_label = 'Petal Length'
p.yaxis.axis_label = 'Petal Width'

for variety in temp.index.unique():
    p.circle(temp.loc[variety,'petal_length'], temp.loc[variety,"petal_width"],
         color=temp.loc[variety,"colors"], fill_alpha=0.2, size=10, legend=variety)

p.legend.location = "top_left"
show(p)
# Out:
# Index(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa',
#        ...
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica'],
#       dtype='object', name='species', length=150)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b61dc966-a2ff-4b68-a43a-b9301fcf78a6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b61dc966-a2ff-4b68-a43a-b9301fcf78a6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b61dc966-a2ff-4b68-a43a-b9301fcf78a6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b61dc966-a2ff-4b68-a43a-b9301fcf78a6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9400e4eb-a20d-4a8e-8ecf-deaa3b5edf13":{"roots":{"references":[{"attributes":{"data_source":{"id":"29fee096-dca3-4f41-9604-b538e287f936","type":"ColumnDataSource"},"glyph":{"id":"de12ea06-92b7-4b5a-a803-7f43fb93650a","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4b70fb4a-3630-476c-96d5-452d53668d37","type":"Circle"},"selection_glyph":null},"id":"0cc31321-864a-4f5c-882f-65413b9ed16d","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","fill_color","line_color"],"data":{"fill_color":["green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green"],"line_color":["green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green"],"x":{"__ndarray__":"...","dtype":"float64","shape":[50]},"y":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"4ebb5827-50a9-4c2b-a6e8-3b6a6459eb54","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"field":"fill_color"},"line_color":{"field":"line_color"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"de12ea06-92b7-4b5a-a803-7f43fb93650a","type":"Circle"},{"attributes":{"plot":{"id":"1dc0260c-e968-466a-b82a-38b091ba1914","subtype":"Figure","type":"Plot"}},"id":"abfce3d0-67a7-4126-8254-bf71064a4714","type":"HelpTool"},{"attributes":{"label":{"value":"virginica"},"renderers":[{"id":"0cc31321-864a-4f5c-882f-65413b9ed16d","type":"GlyphRenderer"}]},"id":"e8193ec8-6496-4da9-99e0-9dda88ea6aa6","type":"LegendItem"},{"attributes":{"plot":{"id":"1dc0260c-e968-466a-b82a-38b091ba1914","subtype":"Figure","type":"Plot"}},"id":"468cb3d0-ae14-4ea3-83be-1c3bbe409d7d","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"4b70fb4a-3630-476c-96d5-452d53668d37","type":"Circle"},{"attributes":{"items":[{"id":"be084856-129d-4f20-bcf1-0808e5153d28","type":"LegendItem"},{"id":"3171611f-6b8e-413b-b4d8-10bebb6ba751","type":"LegendItem"},{"id":"e8193ec8-6496-4da9-99e0-9dda88ea6aa6","type":"LegendItem"}],"location":"top_left","plot":{"id":"1dc0260c-e968-466a-b82a-38b091ba1914","subtype":"Figure","type":"Plot"}},"id":"30de7a15-c788-403c-8a83-054cb511cf64","type":"Legend"},{"attributes":{},"id":"15c65f06-d8dd-48c9-94a5-ab7d87a5d73c","type":"BasicTicker"},{"attributes":{},"id":"ad54128b-43b7-4b89-af90-2ae15e757493","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"setosa"},"renderers":[{"id":"6731c651-834f-4d32-91cc-966a07c4a876","type":"GlyphRenderer"}]},"id":"be084856-129d-4f20-bcf1-0808e5153d28","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y","fill_color","line_color"],"data":{"fill_color":["blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue"],"line_color":["blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","b ...

# %% [markdown]
# Here is just another example of how to add a legend using a column data source method with different data.

# %%
from bokeh.models import ColumnDataSource, CategoricalColorMapper
from bokeh.palettes import RdBu3

source = ColumnDataSource(dict(
    x=[1, 2, 3, 4, 5, 6],
    y=[2, 1, 2, 1, 2, 1],
    label=['hi', 'lo', 'hi', 'lo', 'hi', 'lo']
))
color_mapper = CategoricalColorMapper(factors=['hi', 'lo'], palette=[RdBu3[2], RdBu3[0]])

p = figure(x_range=(0, 7), y_range=(0, 3), height=300, tools='save')
p.circle(
    x='x', y='y', radius=0.5, source=source,
    color={'field': 'label', 'transform': color_mapper},
    legend='label'
)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="47258bb0-8537-4fa6-b963-d4d80a0ca358"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("47258bb0-8537-4fa6-b963-d4d80a0ca358");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("47258bb0-8537-4fa6-b963-d4d80a0ca358");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '47258bb0-8537-4fa6-b963-d4d80a0ca358' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bf4cb0df-6841-4934-bd65-3d8fa2ecdd3f":{"roots":{"references":[{"attributes":{"fill_color":{"field":"label","transform":{"id":"ff11ac66-c442-480a-a9d7-4e5b0b777547","type":"CategoricalColorMapper"}},"line_color":{"field":"label","transform":{"id":"ff11ac66-c442-480a-a9d7-4e5b0b777547","type":"CategoricalColorMapper"}},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"9c5e699c-6be7-4b2d-b3be-ebd35d0bcf39","type":"Circle"},{"attributes":{"formatter":{"id":"2fcac929-ff28-4cff-974b-f63cc315f620","type":"BasicTickFormatter"},"plot":{"id":"0fc7eac8-015d-40d4-8ef9-daea9b25f4fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"413657f0-8917-42f6-81e0-ccad84ed2f08","type":"BasicTicker"}},"id":"87fae611-de97-49bd-8419-477e1d239ba0","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"0fc7eac8-015d-40d4-8ef9-daea9b25f4fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"413657f0-8917-42f6-81e0-ccad84ed2f08","type":"BasicTicker"}},"id":"f07a1251-2bf6-4bef-9f22-629cc7161a1e","type":"Grid"},{"attributes":{"callback":null,"end":3},"id":"4c6d57d0-3c8c-49e8-bde0-dc597325583c","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"cc3e934d-5d51-4f52-afd9-0efd4a773e1a","type":"Circle"},{"attributes":{"data_source":{"id":"7a452f0e-9758-4e48-91c1-6082996c1b46","type":"ColumnDataSource"},"glyph":{"id":"9c5e699c-6be7-4b2d-b3be-ebd35d0bcf39","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"cc3e934d-5d51-4f52-afd9-0efd4a773e1a","type":"Circle"},"selection_glyph":null},"id":"153b0357-10c9-4888-8b39-733668cafd9e","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"9d6dbc6c-a6cf-4087-9020-d0d51da24e91","type":"LinearAxis"}],"left":[{"id":"87fae611-de97-49bd-8419-477e1d239ba0","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"9d6dbc6c-a6cf-4087-9020-d0d51da24e91","type":"LinearAxis"},{"id":"bac57e86-c22c-40cf-8f63-5237f5335ea2","type":"Grid"},{"id":"87fae611-de97-49bd-8419-477e1d239ba0","type":"LinearAxis"},{"id":"f07a1251-2bf6-4bef-9f22-629cc7161a1e","type":"Grid"},{"id":"4b9a244d-acac-4e0c-815a-a918f5d6b1ec","type":"Legend"},{"id":"153b0357-10c9-4888-8b39-733668cafd9e","type":"GlyphRenderer"}],"title":{"id":"51a2e72e-533a-4f7c-80ea-d7801bd8145f","type":"Title"},"tool_events":{"id":"79a13cb6-faf4-4076-830c-a4ea91b92676","type":"ToolEvents"},"toolbar":{"id":"f237f4f1-577a-4445-bceb-ba1c3cc5d980","type":"Toolbar"},"x_range":{"id":"a763af5c-6d3d-49c2-9ff0-1fe37fbb7923","type":"Range1d"},"x_scale":{"id":"3ddb90bd-f180-4793-8f31-76c1250f7790","type":"LinearScale"},"y_range":{"id":"4c6d57d0-3c8c-49e8-bde0-dc597325583c","type":"Range1d"},"y_scale":{"id":"eeadcec8-4bfc-4148-855f-5c82964b148c","type":"LinearScale"}},"id":"0fc7eac8-015d-40d4-8ef9-daea9b25f4fb","subtype":"Figure","type":"Plot"},{"attributes":{"label":{"field":"label"},"renderers":[{"id":"153b0357-10c9-4888-8b39-733668cafd9e","type":"GlyphRenderer"}]},"id":"f15c8efc-eb5c-4ba6-ab50-8326ff457221","type":"LegendItem"},{"attributes":{"factors":["hi","lo"],"palette":["#ef8a62","#67a9cf"]},"id":"ff11ac66-c442-480a-a9d7-4e5b0b777547","type":"CategoricalColorMapper"},{"attributes":{},"id":"2fcac929-ff28-4cff-974b-f63cc315f620","type":"BasicTickFormatter"},{"attributes":{},"id":"3ddb90bd-f180-4793-8f31-76c1250f7790","type":"LinearScale"},{"attributes":{"callback":null,"column_names":["x","y","label"],"data":{"label":["hi","lo","hi","lo","hi","lo"],"x":[1,2,3,4,5,6],"y":[2,1,2,1,2,1]}},"id":"7a452f0e-9758-4e48-91c1-6082996c1b46","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"0fc7eac8-015d-40d4-8ef9-daea9b25f4fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"0b072a43-abba-4aa9-8ee2-04b9418aecce","type":"BasicTicker"}},"id":"bac57e86-c22c-40cf-8f63-5237f5335ea2","type":"Grid"},{"attributes":{"callback":nu ...

# %% [markdown]
# And another way to iteratively add lines to a plot and define different legend attributes

# %%
x = np.linspace(0.1, 5, 100)

p = figure(title="log axis example", y_axis_type="log",
           y_range=(0.001, 10**22))

p.line(x, np.sqrt(x), legend="y=sqrt(x)",
       line_color="tomato", line_dash="dotdash")

p.line(x, x, legend="y=x")
p.circle(x, x, legend="y=x")

p.line(x, x**2, legend="y=x**2")
p.circle(x, x**2, legend="y=x**2",
         fill_color=None, line_color="olivedrab")

p.line(x, 10**x, legend="y=10^x",
       line_color="gold", line_width=2)

p.line(x, x**x, legend="y=x^x",
       line_dash="dotted", line_color="indigo", line_width=2)

p.line(x, 10**(x**2), legend="y=10^(x^2)",
       line_color="coral", line_dash="dashed", line_width=2)

p.legend.location = "top_left"

output_file("logplot.html", title="log plot example")

show(p)  # open a browser
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="37693412-20c5-4a52-bb59-39f875a6d1eb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("37693412-20c5-4a52-bb59-39f875a6d1eb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("37693412-20c5-4a52-bb59-39f875a6d1eb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '37693412-20c5-4a52-bb59-39f875a6d1eb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"341dabec-a0fe-410a-9e70-f627352f0d6a":{"roots":{"references":[{"attributes":{"fill_color":{"value":null},"line_color":{"value":"olivedrab"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f1ef70e5-fee9-4cb8-b1d8-7e83d1fc8aff","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":